# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_data(url):
    # Send a GET request to the website
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code != 200:
        return None
    
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')

     # Find all the links on the page
    links = soup.find_all('a')
    
    # Print the links
    for link in links:
        print(link.get('href'))

    
    # Find the data table in the HTML
    table = soup.find('table')
    
    # Check if the table was found
    if table is None:
        return None
    
    # Extract the header and data rows from the table
    header = [th.text.strip() for th in table.find_all('th')]
    rows = [[td.text.strip() for td in tr.find_all('td')] for tr in table.find_all('tr')]
    
    # Create a pandas dataframe from the header and data rows
    df = pd.DataFrame(rows, columns=header)
    
    return df

# Scrape the data
url = input("Enter the URL of the website to scrape: ") # replace this with the URL of the website you want to scrape
df = scrape_data(url)

# Check if the data was successfully scraped
if df is None:
    print("Error: Failed to scrape Table")
else:
    # Print the first 5 rows of the data
    print(df.head())
# Out:
# Enter the URL of the website to scrape: https://www.mygov.in/covid-19
# https://www.india.gov.in/
# javascript:void(0)
# /covid-19/
# /hi/covid-19/
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# #
# #
# /screenreader/
# javascript:void(0)
# https://twitter.com/mygovindia
# https://www.facebook.com/MyGovIndia
# https://www.youtube.com/mygovindia
# https://www.instagram.com/mygovindia/
# https://www.mygov.in/
# https://g20.mygov.in/
# javascript:void(0)
# javascript:void(0)
# /groups/
# /home/do/
# /home/discuss/
# /home/poll/
# /home/blog/
# /home.talk
# /campaigns/
# /mygov-podcast/
# javascript:void(0)
# https://arunachal.mygov.in
# https://assam.mygov.in
# https://chhattisgarh.mygov.in
# https://goa.mygov.in
# https://gujarat.mygov.in
# https://haryana.mygov.in
# https://jk.mygov.in
# https://karnataka.mygov.in
# https://mp.mygov.in
# https://maharashtra.mygov.in
# https://manipur.mygov.in
# https://tripura.mygov.in
# ...
