# %%
# !pip install py-AutoClean
# !pip install pydataset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 58 kB 2.5 MB/s
# ...
#   Created wheel for py-AutoClean: filename=py_AutoClean-1.1.3-py3-none-any.whl size=10287 sha256=416f5bc229c593b7bc9305cbfdddcc5f956ecc3d14f392c6dffc845be2a172f7
#   Stored in directory: /root/.cache/pip/wheels/ad/4f/67/954c8ee23fbd4bd1cf075d267714fcd98fd9ef7b2514be8954
# Successfully built py-AutoClean
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 15.9 MB 780 kB/s
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939432 sha256=4f575a476701179c21b4838dcbff5277c1e67897987b605168e616106b15e7af
#   Stored in directory: /root/.cache/pip/wheels/d7/e5/36/85d319586b4a405d001029d489102f526ce5546248c295932a
# Successfully built pydataset
# ...

# %%
from pydataset import data

# %%
data()
# Out:
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
df = data('BJsales')
df
# Out:
#      time  BJsales
# 1       1    200.1
# 2       2    199.5
# 3       3    199.4
# 4       4    198.9
# 5       5    199.0
# 6       6    200.2
# 7       7    198.6
# 8       8    200.0
# 9       9    200.3
# 10     10    201.2
# 11     11    201.6
# 12     12    201.5
# 13     13    201.5
# 14     14    203.5
# 15     15    204.9
# 16     16    207.1
# 17     17    210.5
# 18     18    210.5
# 19     19    209.8
# 20     20    208.8
# 21     21    209.5
# 22     22    213.2
# 23     23    213.7
# 24     24    215.1
# 25     25    218.7
# 26     26    219.8
# 27     27    220.5
# 28     28    223.8
# 29     29    222.8
# 30     30    223.8
# 31     31    221.7
# 32     32    222.3
# 33     33    220.8
# 34     34    219.4
# 35     35    220.1
# 36     36    220.6
# 37     37    218.9
# 38     38    217.8
# 39     39    217.7
# 40     40    215.0
# 41     41    215.3
# 42     42    215.9
# 43     43    216.7
# 44     44    216.7
# 45     45    217.7
# 46     46    218.7
# ...

# %%
from AutoClean import AutoClean
pipeline = AutoClean(df, mode='auto', duplicates=True, missing_num=True, missing_categ=True, 
          encode_categ=True, extract_datetime=True, outliers=True, outlier_param=1.5, 
          logfile=True, verbose=True)
# Out:
# 21-12-2022 05:27:48.95 - INFO - Started validation of input parameters...
# 21-12-2022 05:27:48.95 - INFO - Completed validation of input parameters
# 21-12-2022 05:27:48.96 - INFO - Started handling of duplicates... Method: "AUTO"
# 21-12-2022 05:27:48.96 - DEBUG - 0 missing values found
# 21-12-2022 05:27:48.97 - INFO - Completed handling of duplicates in 0.006887 seconds
# 21-12-2022 05:27:48.97 - INFO - Started handling of missing values...
# 21-12-2022 05:27:48.97 - DEBUG - 0 missing values found
# 21-12-2022 05:27:48.98 - INFO - Completed handling of missing values in 0.005013 seconds
# 21-12-2022 05:27:48.98 - INFO - Started handling of outliers... Method: "WINZ"
# 21-12-2022 05:27:48.98 - INFO - Completed handling of outliers in 0.003458 seconds
# 21-12-2022 05:27:48.98 - INFO - Started conversion of DATETIME features... Granularity: s
# 21-12-2022 05:27:48.99 - INFO - Completed conversion of DATETIME features in 0.0021 seconds
# ...

# %%
pipeline.output.shape
# Out:
# (150, 2)
